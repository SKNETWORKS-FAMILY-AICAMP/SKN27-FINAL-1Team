# %%
import pandas as pd
import pathlib

# 데이터 파일 경로 지정
root = pathlib.Path.cwd().parent.parent.parent
file_path       = root / "storage" / "raw" / "recipe" / "recipe.csv"
new_file_path   = root / "storage" / "processed" / "recipe" / "recipe_fix.csv" 

print(root)
print(new_file_path)
# Out:
# c:\dev\project\SKN27-FINAL-1Team
# c:\dev\project\SKN27-FINAL-1Team\storage\processed\recipe\recipe_fix.csv

# %%
# 1차 수정된 파일 로드 
df = pd.read_csv(new_file_path)
df.head(1)
# Out:
#    recipe_id  recipe_name  view_count  scrap_count cooking_method  \
# 0    7038950  명란알게맛살돌솥비빔밥          39            1             볶음
#
#   cooking_situation main_category sub_category  \
# 0               영양식         가공식품류        밥/죽/떡
#
#                                          ingredients serving_size difficulty  \
# 0  [재료] 밥1/2공기| 김치1/2컵| 명란젓1T| 참기름1t|...          2인분         초급
#
#   cooking_time
# 0        10분이내
